# %%
# %cd ../../src

from brane_web import BraneWeb
# Out:
# /Users/carl/Desktop/magnetic_quivers/src

# %%
def generate_braneweb(k1, k2, k3, k4, p, q):

    pass

# %%
braneweb = BraneWeb()

braneweb.add_seven_brane('s1', position=(-1,0))
braneweb.add_seven_brane('s2', position=(1,0))
braneweb.add_seven_brane('s3', position=(2,0))
braneweb.add_seven_brane('s4', position=(3,0))
braneweb.add_seven_brane('s5', position=(4,0))
braneweb.add_seven_brane('s6', position=(5,0))
braneweb.add_seven_brane('s7', position=(6,0))

braneweb.add_seven_brane('st1', position=(-3,1))
braneweb.add_seven_brane('st2', position=(-2,1))
braneweb.add_seven_brane('st3', position=(-1,1))

braneweb.add_seven_brane('sb1', position=(-1,-1))
braneweb.add_seven_brane('sb2', position=(0,-1))
braneweb.add_seven_brane('sb3', position=(2,-1))

braneweb.add_junction('j1', position=(0,0))

braneweb.add_brane('s1', 'j1', multiplicity=1)
braneweb.add_brane('j1', 's2', multiplicity=6)
braneweb.add_brane('s2', 's3', multiplicity=5)
braneweb.add_brane('s3', 's4', multiplicity=4)
braneweb.add_brane('s4', 's5', multiplicity=3)
braneweb.add_brane('s5', 's6', multiplicity=2)
braneweb.add_brane('s6', 's7', multiplicity=1)

braneweb.add_brane('j1', 'st1', multiplicity=1)
braneweb.add_brane('j1', 'st2', multiplicity=1)
braneweb.add_brane('j1', 'st3', multiplicity=1)

braneweb.add_brane('j1', 'sb1', multiplicity=1)
braneweb.add_brane('j1', 'sb2', multiplicity=1)
braneweb.add_brane('j1', 'sb3', multiplicity=1)

braneweb.draw()

# %%
subwebs = braneweb.subwebs()

for subweb in subwebs:
    webweb = BraneWeb.from_subgraph_edges(braneweb.web, subweb)
    webweb.draw()
# Out:
# [('j1', 's1'), ('j1', 's2')]
# [('j1', 'st2'), ('j1', 'sb3')]
# [('j1', 's1'), ('j1', 'st3'), ('j1', 'sb3')]
# [('j1', 's2'), ('j1', 'st1'), ('j1', 'sb3')]
# [('j1', 's2'), ('j1', 'st3'), ('j1', 'sb2')]
# [('j1', 's2'), ('j1', 's2'), ('j1', 'st2'), ('j1', 'sb2'), ('s2', 's3')]
# [('j1', 's2'), ('j1', 's2'), ('j1', 'st3'), ('j1', 'sb1'), ('s2', 's3')]
# [('j1', 's2'), ('j1', 's2'), ('j1', 's2'), ('j1', 'st1'), ('j1', 'sb2'), ('s3', 's4'), ('s2', 's3'), ('s2', 's3')]
# [('j1', 's2'), ('j1', 's2'), ('j1', 's2'), ('j1', 'st2'), ('j1', 'sb1'), ('s3', 's4'), ('s2', 's3'), ('s2', 's3')]
# [('j1', 's2'), ('j1', 's2'), ('j1', 's2'), ('j1', 's2'), ('j1', 'st1'), ('j1', 'sb1'), ('s4', 's5'), ('s3', 's4'), ('s3', 's4'), ('s2', 's3'), ('s2', 's3'), ('s2', 's3')]
# [('s2', 's3')]
# [('s3', 's4')]
# [('s4', 's5')]
# [('s5', 's6')]
# [('s6', 's7')]

# %%
decompositions = braneweb.decompositions()
print(len(decompositions))

for decomposition in decompositions:
    print('Decomposition')
    for subweb in decomposition:
        webweb = BraneWeb.from_subgraph_edges(braneweb.web, subweb)
        webweb.draw()
# Out:
# 6
# Decomposition
# Decomposition
# Decomposition
# Decomposition
# Decomposition
# Decomposition

# %%
magnetic_quivers = braneweb.magnetic_quivers()

for quiver in magnetic_quivers:
    quiver.draw()
