# %% [markdown]
# ## Unit testing magnetic_quivers() function

# %% [markdown]
# #### Initializing

# %%
# %cd ../../src

from brane_web import BraneWeb
from utils import init_example_branewebs
# Out:
# /Users/carl/Desktop/magnetic_quivers/src

# %% [markdown]
# #### brane webs

# %%
branewebs = init_example_branewebs()

# %% [markdown]
# #### magnetic quivers

# %%
for braneweb in branewebs:
    print('-'*80)
    print('Current Braneweb:')
    print('-'*80)
    braneweb.draw()

    magnetic_quivers = braneweb.magnetic_quivers()
    for quiver in magnetic_quivers:
        quiver.draw()

    print()
    print()
# Out:
# --------------------------------------------------------------------------------
# Current Braneweb:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Current Braneweb:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Current Braneweb:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Current Braneweb:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Current Braneweb:
# --------------------------------------------------------------------------------
# ...
