# %%
# %cd ../../src

from brane_web import BraneWeb
# Out:
# /Users/carl/Desktop/magnetic_quivers/src

# %%
web = BraneWeb()

web.add_seven_brane('7b_1', position=(-2, 0))
web.add_seven_brane('7b_2', position=(-1, 0))

web.add_seven_brane('7b_top', position=(0, 1))
web.add_seven_brane('7b_bottom', position=(0, -1))

web.add_seven_brane('7b_3', position=(1, 1))
web.add_seven_brane('7b_4', position=(1, -1))

web.add_junction('j1', position=(0,0))

web.add_brane('7b_1', '7b_2', multiplicity=1)
web.add_brane('7b_2', 'j1', multiplicity=4)
web.add_brane('j1', '7b_3', multiplicity=2)
web.add_brane('j1', '7b_4', multiplicity=2)
web.add_brane('j1', '7b_top', multiplicity=1)
web.add_brane('j1', '7b_bottom', multiplicity=1)

web.draw()  # visualize the brane web

# %%
decompositions = web.subweb_decompositions()
# Out:
# Found 5 decompositions before applying the new rule
# Found 1 maximal decompositions after applying the new rule

# %%
for decomp in decompositions:
    print('-'*30)
    print('Decomposition:', decomp)
    for subweb in decomp:
        print('Subweb edges:', subweb)
        subweb = BraneWeb.from_subgraph_edges(web.web, subweb)
        subweb.draw()
# Out:
# ------------------------------
# Decomposition: [(('7b_2', 'j1'), ('7b_top', 'j1'), ('7b_4', 'j1')), (('7b_2', 'j1'), ('7b_bottom', 'j1'), ('7b_3', 'j1')), (('7b_1', '7b_2'), ('7b_2', 'j1'), ('7b_2', 'j1'), ('7b_3', 'j1'), ('7b_4', 'j1'))]
# Subweb edges: (('7b_2', 'j1'), ('7b_top', 'j1'), ('7b_4', 'j1'))
# Subweb edges: (('7b_2', 'j1'), ('7b_bottom', 'j1'), ('7b_3', 'j1'))
# Subweb edges: (('7b_1', '7b_2'), ('7b_2', 'j1'), ('7b_2', 'j1'), ('7b_3', 'j1'), ('7b_4', 'j1'))
