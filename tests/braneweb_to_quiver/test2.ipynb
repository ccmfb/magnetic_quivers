# %%
# %cd ../../src

from brane_web import BraneWeb
# Out:
# /Users/carl/Desktop/magnetic_quivers/src

# %%
web = BraneWeb()

web.add_seven_brane('7b_left', position=(-1, 0))
web.add_seven_brane('7b_bottom', position=(0, -1))
web.add_seven_brane('7b_topright', position=(1, 1))

web.add_junction('middle', position=(0, 0))

web.add_brane('7b_left', 'middle', multiplicity=1)
web.add_brane('7b_bottom', 'middle', multiplicity=1)
web.add_brane('7b_topright', 'middle', multiplicity=1)

web.draw()

# %%
web = BraneWeb()

web.add_seven_brane('7b_1', position=(-2, 0))
web.add_seven_brane('7b_2', position=(-1, 0))
web.add_seven_brane('7b_3', position=(1, 0))
web.add_seven_brane('7b_4', position=(2, 0))

web.add_seven_brane('7b_bottom1', position=(0, -1))
web.add_seven_brane('7b_bottom2', position=(1, -1))

web.add_seven_brane('7b_top1', position=(0, 1))
web.add_seven_brane('7b_top2', position=(-1, 1))

web.add_junction('j1', position=(0, 0))

web.add_brane('7b_1', '7b_2', multiplicity=1)
web.add_brane('7b_2', 'j1', multiplicity=2)
web.add_brane('j1', '7b_3', multiplicity=2)
web.add_brane('7b_3', '7b_4', multiplicity=1)

web.add_brane('7b_bottom1', 'j1', multiplicity=1)
web.add_brane('7b_bottom2', 'j1', multiplicity=1)

web.add_brane('7b_top1', 'j1', multiplicity=1)
web.add_brane('7b_top2', 'j1', multiplicity=1)

web.draw()

# %%
subwebs = web.find_subweb_decompositions(start_brane=('7b_top1', 'j1'))
# Out:
# r =  1
# comb =  (('j1', '7b_2'),)
# comb =  (('j1', '7b_3'),)
# comb =  (('j1', '7b_bottom1'),)
# comb =  (('j1', '7b_bottom2'),)
# comb =  (('j1', '7b_top2'),)
#
# r =  2
# comb =  (('j1', '7b_2'), ('j1', '7b_3'))
# comb =  (('j1', '7b_2'), ('j1', '7b_bottom1'))
# comb =  (('j1', '7b_2'), ('j1', '7b_bottom2'))
# comb =  (('j1', '7b_2'), ('j1', '7b_top2'))
# comb =  (('j1', '7b_3'), ('j1', '7b_bottom1'))
# comb =  (('j1', '7b_3'), ('j1', '7b_bottom2'))
# comb =  (('j1', '7b_3'), ('j1', '7b_top2'))
# comb =  (('j1', '7b_bottom1'), ('j1', '7b_bottom2'))
# comb =  (('j1', '7b_bottom1'), ('j1', '7b_top2'))
# comb =  (('j1', '7b_bottom2'), ('j1', '7b_top2'))
#
# r =  3
# comb =  (('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_bottom1'))
# comb =  (('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_bottom2'))
# comb =  (('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'))
# comb =  (('j1', '7b_2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'))
# comb =  (('j1', '7b_2'), ('j1', '7b_bottom1'), ('j1', '7b_top2'))
# comb =  (('j1', '7b_2'), ('j1', '7b_bottom2'), ('j1', '7b_top2'))
# comb =  (('j1', '7b_3'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'))
# comb =  (('j1', '7b_3'), ('j1', '7b_bottom1'), ('j1', '7b_top2'))
# comb =  (('j1', '7b_3'), ('j1', '7b_bottom2'), ('j1', '7b_top2'))
# comb =  (('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top2'))
#
# r =  4
# comb =  (('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'))
# comb =  (('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_bottom1'), ('j1', '7b_top2'))
# comb =  (('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_bottom2'), ('j1', '7b_top2'))
# comb =  (('j1', '7b_2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top2'))
# comb =  (('j1', '7b_3'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top2'))
#
# r =  5
# comb =  (('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top2'))
#
# len candidates =  31
