# %%
# %cd ../../src

from brane_web import BraneWeb
# Out:
# /Users/carl/Desktop/magnetic_quivers/src

# %%
web = BraneWeb()

web.add_seven_brane('7b_1', position=(-2, 0))
web.add_seven_brane('7b_2', position=(-1, 0))
web.add_seven_brane('7b_3', position=(1, 0))
web.add_seven_brane('7b_4', position=(2, 0))

web.add_seven_brane('7b_bottom1', position=(0, -1))
web.add_seven_brane('7b_bottom2', position=(1, -1))

web.add_seven_brane('7b_top1', position=(0, 1))
web.add_seven_brane('7b_top2', position=(-1, 1))

web.add_junction('j1', position=(0, 0))

web.add_brane('7b_1', '7b_2', multiplicity=1)
web.add_brane('7b_2', 'j1', multiplicity=2)
web.add_brane('j1', '7b_3', multiplicity=2)
web.add_brane('7b_3', '7b_4', multiplicity=1)

web.add_brane('7b_bottom1', 'j1', multiplicity=1)
web.add_brane('7b_bottom2', 'j1', multiplicity=1)

web.add_brane('7b_top1', 'j1', multiplicity=1)
web.add_brane('7b_top2', 'j1', multiplicity=1)

web.draw()

# %%
subwebs = web.find_subwebs_across_junction('j1')
# Out:
# candidate =  (('j1', '7b_2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_3'))
# candidate =  (('j1', '7b_2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_3'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1'), ('j1', '7b_top2'))
# candidate =  (('j1', '7b_2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_3'), ('j1', '7b_bottom1'), ('j1', '7b_top1'))
# candidate =  (('j1', '7b_2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_3'), ('j1', '7b_bottom2'), ('j1', '7b_top2'))
# candidate =  (('j1', '7b_2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_bottom2'), ('j1', '7b_top1'))
# candidate =  (('j1', '7b_2'), ('j1', '7b_3'))
# candidate =  (('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_3'), ('j1', '7b_bottom1'), ('j1', '7b_top2'))
# candidate =  (('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1'), ('j1', '7b_top2'))
# candidate =  (('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_bottom1'), ('j1', '7b_top1'))
# candidate =  (('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_bottom2'), ('j1', '7b_top2'))
# candidate =  (('j1', '7b_2'), ('j1', '7b_bottom2'), ('j1', '7b_top1'))
# candidate =  (('j1', '7b_3'), ('j1', '7b_bottom1'), ('j1', '7b_top2'))
# candidate =  (('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1'), ('j1', '7b_top2'))
# candidate =  (('j1', '7b_bottom1'), ('j1', '7b_top1'))
# candidate =  (('j1', '7b_bottom2'), ('j1', '7b_top2'))
# len valid candidates =  15
# removing candidate {('j1', '7b_2'), ('j1', '7b_3')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3')}
# removing candidate {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')} as it is not minimal, since it contains {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_3'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_3'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_3'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom2'), ('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_bottom2'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_bottom2'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom2'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom2'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom2'), ('j1', '7b_top2')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top2'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top2'), ('j1', '7b_top1')}
# removing candidate {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')} as it is not minimal, since it contains {('j1', '7b_2'), ('j1', '7b_3'), ('j1', '7b_top2'), ('j1', '7b_bottom1'), ('j1', '7b_bottom2'), ('j1', '7b_top1')}
# len minimal candidates =  5

# %%
for i, subweb in enumerate(subwebs):
    subweb.draw()

# %%
min_set = [(1,2), (3,4)]
min_set = set(min_set)

other_set = [(1,2), (5,6), (3,4)]
other_set = set(other_set)

if min_set.issubset(other_set):
    print('yes')
else:
    print('no')
# Out:
# yes
